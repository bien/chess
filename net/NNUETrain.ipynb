# %%
import pgntrain
import tensorflow as tf
import keras.activations
from livelossplot import PlotLossesKeras
print(f"TensorFlow has access to the following devices:\n{tf.config.list_physical_devices()}")
# Out:
# TensorFlow has access to the following devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
pgnfile = ['lichess_db_standard_rated_2024-01.pgn.zst', 'lichess_db_standard_rated_2024-02.pgn.zst']
validation_pgn = 'lichess_db_standard_rated_2024-03.50M.pgn'

# %%
size = 16
layers = 0
n = pgntrain.BasicNNUE(num_hidden_layers=0, half_len_concat=size)
model = n.train(pgnfile, validation_pgn, profile=False, batch_size=256, validation_steps=8, steps_per_epoch=4096, epochs=10, callbacks=[PlotLossesKeras()], verbose=2)
model.save(f'nnue-0-layer-{size}.keras')
# Out:
# cp_final_loss
# 	training         	 (min:    1.495, max:    2.392, cur:    1.715)
# 	validation       	 (min:    1.007, max:    1.181, cur:    1.169)
# cp_final_mean_squared_error
# 	training         	 (min:    1.495, max:    2.392, cur:    1.715)
# 	validation       	 (min:    1.007, max:    1.181, cur:    1.169)
# Loss
# 	training         	 (min:    0.819, max:    1.105, cur:    0.852)
# 	validation       	 (min:    0.708, max:    0.797, cur:    0.746)
# wdl_categorical_accuracy
# 	validation       	 (min:    0.773, max:    0.807, cur:    0.803)
# 	training         	 (min:    0.731, max:    0.794, cur:    0.794)
# wdl_loss
# 	validation       	 (min:    0.498, max:    0.561, cur:    0.513)
# 	training         	 (min:    0.509, max:    0.627, cur:    0.509)
# ...

# %%
size = 16
layers = 1
n = pgntrain.BasicNNUE(num_hidden_layers=0, half_len_concat=size)
model = n.train(pgnfile, validation_pgn, profile=False, batch_size=256, validation_steps=8, steps_per_epoch=4096, epochs=10, callbacks=[PlotLossesKeras()], verbose=2)
model.save(f'nnue-{layers}-layer-{size}.keras')
# Out:
# cp_final_loss
# 	training         	 (min:    1.490, max:    2.376, cur:    1.707)
# 	validation       	 (min:    0.954, max:    1.206, cur:    1.084)
# cp_final_mean_squared_error
# 	training         	 (min:    1.490, max:    2.376, cur:    1.707)
# 	validation       	 (min:    0.954, max:    1.206, cur:    1.084)
# Loss
# 	training         	 (min:    0.835, max:    1.108, cur:    0.861)
# 	validation       	 (min:    0.707, max:    0.815, cur:    0.735)
# wdl_categorical_accuracy
# 	validation       	 (min:    0.767, max:    0.794, cur:    0.779)
# 	training         	 (min:    0.728, max:    0.789, cur:    0.789)
# wdl_loss
# 	validation       	 (min:    0.515, max:    0.573, cur:    0.518)
# 	training         	 (min:    0.520, max:    0.633, cur:    0.520)
# ...

# %%
size = 128
layers = 1
n = pgntrain.BasicNNUE(num_hidden_layers=layers, half_len_concat=size)
model = n.train(pgnfile, validation_pgn, profile=False, batch_size=256, validation_steps=8, steps_per_epoch=4096, epochs=20, callbacks=[PlotLossesKeras()], verbose=2)
model.save(f'nnue-{layers}-layer-{size}.keras')
# Out:
# cp_final_loss
# 	training         	 (min:    1.253, max:    1.913, cur:    1.262)
# 	validation       	 (min:    0.789, max:    1.122, cur:    0.959)
# cp_final_mean_squared_error
# 	training         	 (min:    1.253, max:    1.913, cur:    1.262)
# 	validation       	 (min:    0.789, max:    1.122, cur:    0.959)
# Loss
# 	training         	 (min:    0.634, max:    0.938, cur:    0.636)
# 	validation       	 (min:    0.555, max:    0.721, cur:    0.596)
# wdl_categorical_accuracy
# 	validation       	 (min:    0.796, max:    0.852, cur:    0.846)
# 	training         	 (min:    0.768, max:    0.850, cur:    0.849)
# wdl_loss
# 	validation       	 (min:    0.376, max:    0.496, cur:    0.404)
# 	training         	 (min:    0.383, max:    0.556, cur:    0.383)
# ...

# %%
size = 16
layers = 2
n = pgntrain.BasicNNUE(num_hidden_layers=layers, half_len_concat=size)
model = n.train(pgnfile, validation_pgn, profile=False, batch_size=256, validation_steps=8, steps_per_epoch=4096, epochs=20, callbacks=[PlotLossesKeras()], verbose=2)
model.save(f'nnue-{layers}-layer-{size}.keras')
# Out:
# cp_final_loss
# 	training         	 (min:    1.462, max:    2.737, cur:    1.486)
# 	validation       	 (min:    0.849, max:    1.477, cur:    0.849)
# cp_final_mean_squared_error
# 	training         	 (min:    1.462, max:    2.737, cur:    1.486)
# 	validation       	 (min:    0.849, max:    1.477, cur:    0.849)
# Loss
# 	training         	 (min:    0.759, max:    1.148, cur:    0.763)
# 	validation       	 (min:    0.646, max:    0.841, cur:    0.646)
# wdl_categorical_accuracy
# 	validation       	 (min:    0.771, max:    0.815, cur:    0.804)
# 	training         	 (min:    0.745, max:    0.813, cur:    0.812)
# wdl_loss
# 	validation       	 (min:    0.464, max:    0.546, cur:    0.477)
# 	training         	 (min:    0.466, max:    0.601, cur:    0.466)
# ...

# %%
size = 64
layers = 2
n = pgntrain.BasicNNUE(num_hidden_layers=layers, half_len_concat=size)
model = n.train(pgnfile, validation_pgn, profile=False, batch_size=256, validation_steps=8, steps_per_epoch=4096, epochs=30, callbacks=[PlotLossesKeras()], verbose=2)
model.save(f'nnue-{layers}-layer-{size}.keras')
# Out:
# cp_final_loss
# 	training         	 (min:    1.156, max:    2.551, cur:    1.169)
# 	validation       	 (min:    0.756, max:    1.329, cur:    0.805)
# cp_final_mean_squared_error
# 	training         	 (min:    1.156, max:    2.551, cur:    1.169)
# 	validation       	 (min:    0.756, max:    1.329, cur:    0.805)
# Loss
# 	training         	 (min:    0.637, max:    1.086, cur:    0.640)
# 	validation       	 (min:    0.576, max:    0.779, cur:    0.581)
# wdl_categorical_accuracy
# 	validation       	 (min:    0.779, max:    0.835, cur:    0.825)
# 	training         	 (min:    0.758, max:    0.840, cur:    0.840)
# wdl_loss
# 	validation       	 (min:    0.412, max:    0.513, cur:    0.420)
# 	training         	 (min:    0.406, max:    0.575, cur:    0.406)
# ...

# %%
size = 256
layers = 2
n = pgntrain.BasicNNUE(num_hidden_layers=layers, half_len_concat=size)
model = n.train(pgnfile, validation_pgn, profile=False, batch_size=256, validation_steps=8, steps_per_epoch=4096, epochs=30, callbacks=[PlotLossesKeras()], verbose=2)
model.save(f'nnue-{layers}-layer-{size}.keras')
# Out:
# cp_final_loss
# 	training         	 (min:    1.096, max:    2.508, cur:    1.131)
# 	validation       	 (min:    0.704, max:    1.279, cur:    0.822)
# cp_final_mean_squared_error
# 	training         	 (min:    1.096, max:    2.508, cur:    1.131)
# 	validation       	 (min:    0.704, max:    1.279, cur:    0.822)
# Loss
# 	training         	 (min:    0.592, max:    1.058, cur:    0.597)
# 	validation       	 (min:    0.526, max:    0.739, cur:    0.585)
# wdl_categorical_accuracy
# 	validation       	 (min:    0.798, max:    0.854, cur:    0.838)
# 	training         	 (min:    0.768, max:    0.856, cur:    0.856)
# wdl_loss
# 	validation       	 (min:    0.367, max:    0.483, cur:    0.421)
# 	training         	 (min:    0.371, max:    0.556, cur:    0.371)
# ...

# %%
size = 512
layers = 2
n = pgntrain.BasicNNUE(num_hidden_layers=layers, half_len_concat=size)
model = n.train(pgnfile, validation_pgn, profile=False, batch_size=256, validation_steps=8, steps_per_epoch=4096, epochs=40, callbacks=[PlotLossesKeras()], verbose=2)
model.save(f'nnue-{layers}-layer-{size}.keras')
# Out:
# cp_final_loss
# 	training         	 (min:    1.129, max:    2.016, cur:    1.316)
# 	validation       	 (min:    0.757, max:    1.029, cur:    0.792)
# cp_final_mean_squared_error
# 	training         	 (min:    1.129, max:    2.016, cur:    1.316)
# 	validation       	 (min:    0.757, max:    1.029, cur:    0.792)
# Loss
# 	training         	 (min:    0.585, max:    0.951, cur:    0.620)
# 	validation       	 (min:    0.517, max:    0.652, cur:    0.520)
# wdl_categorical_accuracy
# 	validation       	 (min:    0.816, max:    0.869, cur:    0.855)
# 	training         	 (min:    0.773, max:    0.862, cur:    0.861)
# wdl_loss
# 	validation       	 (min:    0.358, max:    0.457, cur:    0.361)
# 	training         	 (min:    0.357, max:    0.547, cur:    0.357)
# ...
